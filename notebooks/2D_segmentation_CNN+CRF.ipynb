# %%
import sys, os
sys.path.append(os.path.abspath("../"))

import torch
from torch import nn, optim
from tqdm import tqdm

from src.model import DilatedSegCNN
from src.datamodule import make_dataloaders
from src.preprocess import compute_log_bboxes

# %%
from src.train import train_model

model, (train_losses, val_losses, val_ious) = train_model(
    root_dir="../data/old_dataset",
    out_dir="../logs/old_model",
    epochs=200,
    batch_size=8,
    lr=3e-4,
    size=256,
    num_classes=7,
    early_stop_patience=15,
    use_crf=False
    
)

import matplotlib.pyplot as plt
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.plot(val_ious, label="Val IoU")
plt.legend(); plt.show()
# Out:
# ...
# Computing global bbox: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [00:00<00:00, 304.53it/s]
# Computed bounding boxes for 6 logs.
# Scanning dataset: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 517/517 [00:00<00:00, 3801.47it/s]
# Total valid samples: 285
# Split mode: slice | Train=228 | Val=57
# ...

# %%
from src.evaluate import evaluate_model

weights_path = "../logs/old_model/checkpoints/best.pt"
root_dir = "../data/old_dataset"

mean_iou, per_class_ious = evaluate_model(
    weights_path=weights_path,
    root_dir=root_dir,
    num_classes=7,
    batch_size=2,
    size=256
)
# Out:
# ...
# Computing global bbox: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [00:00<00:00, 320.35it/s]
# Computed bounding boxes for 6 logs.
# Scanning dataset: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 517/517 [00:00<00:00, 3976.90it/s]
# Total valid samples: 285
# Split mode: slice | Train=228 | Val=57
# Evaluating: ../logs/old_model/checkpoints/best.pt
# ...

# %%
from src.evaluate import visualize_slices
from src.preprocess import compute_log_bboxes

bbox_dict = compute_log_bboxes(root_dir)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_loader, val_loader = make_dataloaders(
    root_dir=root_dir,
    batch_size=2,
    bbox_dict=bbox_dict,
    size=(256, 256)
)

visualize_slices(model, val_loader, device=device, n_slices=6, start_index=0)
# Out:
# ...
# Computing global bbox: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [00:00<00:00, 323.15it/s]
# Computed bounding boxes for 6 logs.
# Scanning dataset: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 517/517 [00:00<00:00, 3976.88it/s]
# Total valid samples: 285
# Split mode: slice | Train=228 | Val=57
